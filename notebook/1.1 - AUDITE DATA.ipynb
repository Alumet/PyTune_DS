# %% [markdown]
# # AUDITE DES DATAS
#
# FICHIER:
# - *'sentiment_values.csv'*
# - *'user_track_hashtag_timestamp.csv'*
# - *'context_content_features.csv'*

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# ### Chargement des données

# %%
df_sentiment = pd.read_csv('raw data/sentiment_values.csv', sep=';')
df_user = pd.read_csv('raw data/user_track_hashtag_timestamp.csv')
df_content = pd.read_csv('raw data/context_content_features.csv', error_bad_lines=False)
# Out:
# C:\Users\Alumet\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...

# %% [markdown]
# ### Exploration 'sentiment_values.csv'

# %%
df_sentiment.head()
# Out:
#              hashtag   vader_min   vader_max   vader_sum  vader_avg  \
# 0          relaxtime         0.8         0.8         2.4        0.8
# 1  melovechilicheese         0.8         0.8         0.8        0.8
# 2         greatmusic         0.8         0.8         2.4        0.8
# 3         rockballad         0.7         0.7         0.7        0.7
# 4         amonamarth         0.3         0.3         0.3        0.3
#
#      afinn_min   afinn_max   afinn_sum   afinn_avg   ol_min  ...   ol_sum  \
# 0          NaN         NaN         NaN         NaN   0.7375  ...   0.7375
# 1          NaN         NaN         NaN         NaN   0.9000  ...   0.9000
# 2          1.0         1.0         1.0         1.0   0.8875  ...   0.8875
# 3          NaN         NaN         NaN         NaN      NaN  ...      NaN
# 4          NaN         NaN         NaN         NaN      NaN  ...      NaN
#
#     ol_avg   ss_min   ss_max   ss_sum   ss_avg  Unnamed: 17  Unnamed: 18  \
# ...

# %%
# Quels sont les colonnes disponibles
df_sentiment.columns
# Out:
# Index(['hashtag', ' vader_min', ' vader_max', ' vader_sum', 'vader_avg',
#        '  afinn_min', ' afinn_max', ' afinn_sum', ' afinn_avg', ' ol_min',
#        ' ol_max', ' ol_sum', ' ol_avg', ' ss_min', ' ss_max', ' ss_sum',
#        ' ss_avg', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20'],
#       dtype='object')

# %%
# Quels sont les types de chaque colonnes
df_sentiment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hashtag      5290 non-null   object
#  1    vader_min   3867 non-null   float64
#  2    vader_max   3867 non-null   float64
#  3    vader_sum   3867 non-null   float64
#  4   vader_avg    3867 non-null   float64
#  5     afinn_min  255 non-null    float64
#  6    afinn_max   255 non-null    float64
#  7    afinn_sum   255 non-null    float64
#  8    afinn_avg   255 non-null    float64
#  9    ol_min      2635 non-null   float64
#  10   ol_max      2635 non-null   float64
#  11   ol_sum      2635 non-null   float64
#  12   ol_avg      2635 non-null   float64
#  13   ss_min      2823 non-null   float64
#  14   ss_max      2823 non-null   float64
#  15   ss_sum      2823 non-null   float64
#  16   ss_avg      2823 non-null   float64
#  17  Unnamed: 17  2160 non-null   float64
# ...

# %%
# Analyse de la distribution
df_sentiment.describe()
# Out:
#          vader_min    vader_max    vader_sum    vader_avg    afinn_min  \
# count  3867.000000  3867.000000  3867.000000  3867.000000   255.000000
# mean      0.495035     0.513007     0.921877     0.503563     0.745098
# std       0.239754     0.239695     0.629695     0.236347     0.436663
# min       0.100000     0.100000     0.100000     0.100000     0.000000
# 25%       0.300000     0.300000     0.600000     0.300000     0.000000
# 50%       0.400000     0.600000     0.700000     0.600000     1.000000
# 75%       0.700000     0.700000     1.400000     0.700000     1.000000
# max       1.000000     1.000000     4.800000     1.000000     1.000000
#
#         afinn_max   afinn_sum   afinn_avg       ol_min       ol_max  \
# count  255.000000  255.000000  255.000000  2635.000000  2635.000000
# mean     0.752941    0.858824    0.749020     0.523107     0.544905
# std      0.432149    0.648796    0.432158     0.262607     0.260557
# ...

# %%
# Recherche des données manquantes
df_sentiment.isna().sum()/df_sentiment.shape[0]*100
# Out:
# hashtag         0.000000
#  vader_min     26.899811
#  vader_max     26.899811
#  vader_sum     26.899811
# vader_avg      26.899811
#   afinn_min    95.179584
#  afinn_max     95.179584
#  afinn_sum     95.179584
#  afinn_avg     95.179584
#  ol_min        50.189036
#  ol_max        50.189036
#  ol_sum        50.189036
#  ol_avg        50.189036
#  ss_min        46.635161
#  ss_max        46.635161
#  ss_sum        46.635161
#  ss_avg        46.635161
# Unnamed: 17    59.168242
# Unnamed: 18    59.168242
# Unnamed: 19    59.168242
# Unnamed: 20    59.168242
# dtype: float64

# %%
# Dimension du DataFrame
df_sentiment.shape
# Out:
# (5290, 21)

# %%
# Nombre de valeurs unique de la colonne 'hashtag'
df_sentiment['hashtag'].unique().shape
# Out:
# (5290,)

# %% [markdown]
# ### Exploration 'user_track_hashtag_timestamp'

# %%
df_user.head()
# Out:
#       user_id                          track_id     hashtag  \
# 0    81496937  cd52b3e5b51da29e5893dba82a418a4b  nowplaying
# 1    81496937  cd52b3e5b51da29e5893dba82a418a4b        goth
# 2    81496937  cd52b3e5b51da29e5893dba82a418a4b   deathrock
# 3    81496937  cd52b3e5b51da29e5893dba82a418a4b    postpunk
# 4  2205686924  da3110a77b724072b08f231c9d6f7534  NowPlaying
#
#             created_at
# 0  2014-01-01 05:54:21
# 1  2014-01-01 05:54:21
# 2  2014-01-01 05:54:21
# 3  2014-01-01 05:54:21
# 4  2014-01-01 05:54:22

# %%
# Quels sont les colonnes disponibles
df_user.columns
# Out:
# Index(['user_id', 'track_id', 'hashtag', 'created_at'], dtype='object')

# %%
# Quels sont les types de chaque colonnes
df_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17560113 entries, 0 to 17560112
# Data columns (total 4 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   user_id     int64
#  1   track_id    object
#  2   hashtag     object
#  3   created_at  object
# dtypes: int64(1), object(3)
# memory usage: 535.9+ MB

# %%
# Dimension du DataFrame
df_user.shape
# Out:
# (17560113, 4)

# %%
# Recherche des données manquantes
df_user.isna().sum()/df_user.shape[0]*100
# Out:
# user_id       0.000000
# track_id      0.000000
# hashtag       0.000006
# created_at    0.000000
# dtype: float64

# %%
# Analyse de la distribution
df_user.describe()
# Out:
#             user_id
# count  1.756011e+07
# mean   8.857594e+08
# std    8.578935e+08
# min    9.390000e+02
# 25%    1.636055e+08
# 50%    5.314516e+08
# 75%    1.480383e+09
# max    2.937225e+09

# %%
# Nombre de valeurs unique pour chaque colonne
for colum in df_user.columns:
    print(colum, df_user[colum].unique().shape[0])
# Out:
# user_id 138223
# track_id 344536
# hashtag 49913
# created_at 8743896

# %%
# Transformation de colonne created at en timestamp
df_user['created_at_time'] = df_user['created_at'].apply(lambda x: datetime.datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))

# %%
# Date de la premiére entrée
df_user['created_at_time'].min()
# Out:
# Timestamp('2014-01-01 05:54:21')

# %%
# Date de la dernière entrée
df_user['created_at_time'].max()
# Out:
# Timestamp('2014-12-23 07:21:11')

# %% [markdown]
# ### Exploration 'sentiment_values.csv'

# %%
df_content.head()
# Out:
#   coordinates  instrumentalness  liveness  speechiness  danceability  valence  \
# 0         NaN          0.004790    0.1800       0.0294         0.634    0.342
# 1         NaN          0.017700    0.0638       0.0624         0.769    0.752
# 2         NaN          0.000000    0.0860       0.0436         0.675    0.775
# 3         NaN          0.000000    0.1430       0.0292         0.324    0.333
# 4         NaN          0.000183    0.3620       0.0524         0.767    0.808
#
#    loudness    tempo  acousticness  energy  ...  \
# 0    -8.345  125.044       0.00035   0.697  ...
# 1    -8.252   95.862       0.26700   0.826  ...
# 2    -4.432   97.030       0.21700   0.885  ...
# 3    -5.647   74.101       0.23900   0.574  ...
# 4    -5.011  114.237       0.03640   0.739  ...
#
#                           artist_id  place  geo tweet_lang  \
# 0  b2980c722a1ace7a30303718ce5491d8    NaN  NaN         en
# 1  5cddcd0e314e2f2223ab21937d2c8778    NaN  NaN         en
# ...

# %%
# Quels sont les colonnes disponibles
df_content.columns
# Out:
# Index(['coordinates', 'instrumentalness', 'liveness', 'speechiness',
#        'danceability', 'valence', 'loudness', 'tempo', 'acousticness',
#        'energy', 'mode', 'key', 'artist_id', 'place', 'geo', 'tweet_lang',
#        'track_id', 'created_at', 'lang', 'time_zone', 'user_id', 'id'],
#       dtype='object')

# %%
# Quels sont les types de chaque colonnes
df_content.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11606689 entries, 0 to 11606688
# Data columns (total 22 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   coordinates       object
#  1   instrumentalness  float64
#  2   liveness          float64
#  3   speechiness       float64
#  4   danceability      float64
#  5   valence           float64
#  6   loudness          float64
#  7   tempo             float64
#  8   acousticness      float64
#  9   energy            float64
#  10  mode              float64
#  11  key               float64
#  12  artist_id         object
#  13  place             object
#  14  geo               object
#  15  tweet_lang        object
#  16  track_id          object
#  17  created_at        object
#  18  lang              object
#  19  time_zone         object
#  20  user_id           float64
#  21  id                int64
# dtypes: float64(12), int64(1), object(9)
# memory usage: 1.9+ GB

# %%
# Recherche des données manquantes
df_content.isna().sum()
# Out:
# coordinates         11575689
# instrumentalness        2801
# liveness                2913
# speechiness             3887
# danceability            3887
# valence                 4787
# loudness                   0
# tempo                      0
# acousticness            2786
# energy                  2760
# mode                    2713
# key                     2713
# artist_id                  0
# place               11570327
# geo                 11575689
# tweet_lang                 0
# track_id                   0
# created_at                 0
# lang                      64
# time_zone            3260480
# user_id                36362
# id                         0
# dtype: int64

# %%
# Analyse de la distribution
df_content.describe()
# Out:
#        instrumentalness      liveness   speechiness  danceability  \
# count      1.160389e+07  1.160378e+07  1.160280e+07  1.160280e+07
# mean       9.646758e-02  1.914897e-01  6.557175e-02  5.579651e-01
# std        2.386756e-01  1.597826e-01  6.500116e-02  1.580670e-01
# min        0.000000e+00  6.730000e-03  2.160000e-02  3.710000e-02
# 25%        0.000000e+00  9.280000e-02  3.310000e-02  4.540000e-01
# 50%        5.560000e-05  1.280000e-01  4.280000e-02  5.640000e-01
# 75%        1.050000e-02  2.490000e-01  6.740000e-02  6.720000e-01
# max        9.990000e-01  1.000000e+00  9.650000e-01  9.920000e-01
#
#             valence      loudness         tempo  acousticness        energy  \
# count  1.160190e+07  1.160669e+07  1.160669e+07  1.160390e+07  1.160393e+07
# mean   5.165777e-01 -7.688271e+00  1.228332e+02  2.085728e-01  6.815353e-01
# std    2.478481e-01  3.846732e+00  2.830217e+01  2.690466e-01  2.150781e-01
# ...
